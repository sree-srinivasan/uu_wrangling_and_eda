# %% [markdown]
# # Setup of Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

df = pd.read_csv('ForeignGifts_edu.csv')

# %% [markdown]
# # UVA

# %%
uva = df[df['Institution Name'] == ('University of Virginia')]
uva
# Out:
#           ID   OPEID        Institution Name             City State  \
# 26235  26236  374500  University of Virginia  Charlottesville    VA
# 26236  26237  374500  University of Virginia  Charlottesville    VA
# 26237  26238  374500  University of Virginia  Charlottesville    VA
# 26238  26239  374500  University of Virginia  Charlottesville    VA
# 26239  26240  374500  University of Virginia  Charlottesville    VA
# ...      ...     ...                     ...              ...   ...
# 26328  26329  374500  University of Virginia  Charlottesville    VA
# 26329  26330  374500  University of Virginia  Charlottesville    VA
# 26330  26331  374500  University of Virginia  Charlottesville    VA
# 26331  26332  374500  University of Virginia  Charlottesville    VA
# 26332  26333  374500  University of Virginia  Charlottesville    VA
#
#        Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 26235                       41822                 3565  Monetary Gift
# ...

# %% [markdown]
# ## Investigating UVA Donations

# %%
uva_total = uva['Foreign Gift Amount'].sum()
uva_mean = uva['Foreign Gift Amount'].mean()
uva_median = uva['Foreign Gift Amount'].median()

print(uva_total, uva_mean, uva_median)
# Out:
# 22189238 226420.79591836734 80535.5

# %% [markdown]
# # Looking into Peers

# %% [markdown]
# ## VCU

# %%
vcu = df[df['Institution Name'] == ('Virginia Commonwealth University')]
vcu
# Out:
#           ID   OPEID                  Institution Name      City State  \
# 26120  26121  373500  Virginia Commonwealth University  Richmond    VA
# 26121  26122  373500  Virginia Commonwealth University  Richmond    VA
# 26122  26123  373500  Virginia Commonwealth University  Richmond    VA
# 26123  26124  373500  Virginia Commonwealth University  Richmond    VA
# 26124  26125  373500  Virginia Commonwealth University  Richmond    VA
# ...      ...     ...                               ...       ...   ...
# 26230  26231  373500  Virginia Commonwealth University  Richmond    VA
# 26231  26232  373500  Virginia Commonwealth University  Richmond    VA
# 26232  26233  373500  Virginia Commonwealth University  Richmond    VA
# 26233  26234  373500  Virginia Commonwealth University  Richmond    VA
# 26234  26235  373500  Virginia Commonwealth University  Richmond    VA
#
#        Foreign Gift Received Date  Foreign Gift Amount Gift Type  \
# ...

# %% [markdown]
# ### Investigating VCU Donations

# %%
vcu_total = vcu['Foreign Gift Amount'].sum()
vcu_mean = vcu['Foreign Gift Amount'].mean()
vcu_median = vcu['Foreign Gift Amount'].median()

print(vcu_total, vcu_mean, vcu_median)
# Out:
# 89163583 775335.5043478261 33750.0

# %% [markdown]
# ## VT

# %%
vt = df[df['Institution Name'] == ('Virginia Polytechnic Institute & State University')]
vt
# Out:
#           ID   OPEID                                   Institution Name  \
# 26371  26372  375400  Virginia Polytechnic Institute & State University
# 26372  26373  375400  Virginia Polytechnic Institute & State University
# 26373  26374  375400  Virginia Polytechnic Institute & State University
# 26374  26375  375400  Virginia Polytechnic Institute & State University
# 26375  26376  375400  Virginia Polytechnic Institute & State University
# 26376  26377  375400  Virginia Polytechnic Institute & State University
# 26377  26378  375400  Virginia Polytechnic Institute & State University
# 26378  26379  375400  Virginia Polytechnic Institute & State University
# 26379  26380  375400  Virginia Polytechnic Institute & State University
# 26380  26381  375400  Virginia Polytechnic Institute & State University
# 26381  26382  375400  Virginia Polytechnic Institute & State University
# 26382  26383  375400  Virginia Polytechnic Institute & State University
# ...

# %% [markdown]
# ### Investigating VT Donations

# %%
vt_total = vt['Foreign Gift Amount'].sum()
vt_mean = vt['Foreign Gift Amount'].mean()
vt_median = vt['Foreign Gift Amount'].median()

print(vt_total, vt_mean, vt_median)
# Out:
# 11792062 491335.9166666667 350000.0

# %% [markdown]
# ## GMU

# %%
gmu = df[df['Institution Name'] == ('George Mason University')]
gmu
# Out:
#           ID   OPEID         Institution Name     City State  \
# 26333  26334  374900  George Mason University  Fairfax    VA
# 26334  26335  374900  George Mason University  Fairfax    VA
# 26335  26336  374900  George Mason University  Fairfax    VA
# 26336  26337  374900  George Mason University  Fairfax    VA
# 26337  26338  374900  George Mason University  Fairfax    VA
# 26338  26339  374900  George Mason University  Fairfax    VA
# 26339  26340  374900  George Mason University  Fairfax    VA
# 26340  26341  374900  George Mason University  Fairfax    VA
# 26341  26342  374900  George Mason University  Fairfax    VA
# 26342  26343  374900  George Mason University  Fairfax    VA
# 26343  26344  374900  George Mason University  Fairfax    VA
# 26344  26345  374900  George Mason University  Fairfax    VA
# 26345  26346  374900  George Mason University  Fairfax    VA
# 26346  26347  374900  George Mason University  Fairfax    VA
# ...

# %% [markdown]
# ### Investigating GMU Donations

# %%
gmu_total = gmu['Foreign Gift Amount'].sum()
gmu_mean = gmu['Foreign Gift Amount'].mean()
gmu_median = gmu['Foreign Gift Amount'].median()

print(gmu_total, gmu_mean, gmu_median)
# Out:
# 65435604 1721989.5789473683 507053.5

# %% [markdown]
# ## WM

# %%
wm = df[df['Institution Name'] == ('College of William & Mary')]
wm
# Out:
#           ID   OPEID           Institution Name          City State  \
# 26103  26104  370500  College of William & Mary  Williamsburg    VA
# 26104  26105  370500  College of William & Mary  Williamsburg    VA
# 26105  26106  370500  College of William & Mary  Williamsburg    VA
# 26106  26107  370500  College of William & Mary  Williamsburg    VA
# 26107  26108  370500  College of William & Mary  Williamsburg    VA
# 26108  26109  370500  College of William & Mary  Williamsburg    VA
# 26109  26110  370500  College of William & Mary  Williamsburg    VA
# 26110  26111  370500  College of William & Mary  Williamsburg    VA
# 26111  26112  370500  College of William & Mary  Williamsburg    VA
# 26112  26113  370500  College of William & Mary  Williamsburg    VA
# 26113  26114  370500  College of William & Mary  Williamsburg    VA
# 26114  26115  370500  College of William & Mary  Williamsburg    VA
# 26115  26116  370500  College of William & Mary  Williamsburg    VA
# ...

# %% [markdown]
# ### Investigating WM Donations

# %%
wm_total = wm['Foreign Gift Amount'].sum()
wm_mean = wm['Foreign Gift Amount'].mean()
wm_median = wm['Foreign Gift Amount'].median()

print(wm_total, wm_mean, wm_median)
# Out:
# 3384498 199088.11764705883 51600.0

# %% [markdown]
# # Further UVA Investigation

# %% [markdown]
# ## Groupby Sum

# %%
uva.groupby('Country of Giftor')['Foreign Gift Amount'].sum().sort_values(ascending = False)
# Out:
# Country of Giftor
# BERMUDA      7.688837e+06
# ECUADOR      3.985140e+06
# QATAR        3.905109e+06
# ANTIGUA      3.435545e+06
# JERSEY       3.064589e+06
#                  ...
# ST. LUCIA    5.000000e+01
# IRAN         4.000000e+01
# CROATIA      2.600000e+01
# SLOVAKIA     2.000000e+01
# ERITREA      3.000000e+00
# Name: Foreign Gift Amount, Length: 155, dtype: float64

# %% [markdown]
# ## Groupby Size

# %%
uva.groupby('Country of Giftor').size().sort_values(ascending = False)
# Out:
# Country of Giftor
# ENGLAND            31
# ISRAEL             12
# BANGLADESH         10
# SWEDEN             10
# FINLAND             7
# KOREA               6
# FRANCE              5
# THE NETHERLANDS     4
# GUERNSEY            3
# TANZANIA            3
# SINGAPORE           2
# SWITZERLAND         2
# BERMUDA             1
# JAPAN               1
# RWANDA              1
# dtype: int64

# %% [markdown]
# ## Groupby Mean

# %%
df.groupby('Country of Giftor')['Foreign Gift Amount'].mean().sort_values(ascending = False)
# Out:
# Country of Giftor
# BERMUDA      7.688837e+06
# ECUADOR      3.985140e+06
# QATAR        3.905109e+06
# ANTIGUA      3.435545e+06
# JERSEY       3.064589e+06
#                  ...
# ST. LUCIA    5.000000e+01
# IRAN         4.000000e+01
# CROATIA      2.600000e+01
# SLOVAKIA     2.000000e+01
# ERITREA      3.000000e+00
# Name: Foreign Gift Amount, Length: 155, dtype: float64

# %% [markdown]
# ## Top Individual Giftors to UVA

# %%
uva['Gift Type'].value_counts()
# Out:
# Gift Type
# Contract         64
# Monetary Gift    34
# Name: count, dtype: int64

# %% [markdown]
# ## Mean vs Median

# %%
uva_mean = uva['Foreign Gift Amount'].mean()
uva_median = uva['Foreign Gift Amount'].median()

print(uva_mean)
print(uva_median)
# Out:
# 226420.79591836734
# 80535.5

# %% [markdown]
# ### Graph

# %%
sns.histplot(uva['Foreign Gift Amount'], bins = 100, log_scale = True)
plt.axvline(uva_mean, color = 'black')
plt.axvline(uva_median, color = 'grey')
plt.title('Distribution of UVA Foreign Gift Amounts')
# Out:
# Text(0.5, 1.0, 'Distribution of UVA Foreign Gift Amounts')

# %% [markdown]
# ## Crosstab UVA (Giftor Flow)

# %%
uva_flow = pd.crosstab(
    index = uva['Country of Giftor'],
    columns = uva['Giftor Name'],
    values = df['Foreign Gift Amount'],
    aggfunc = 'sum'
)
uva_flow.stack().sort_values(ascending = False).head()
# Out:
# Country of Giftor  Giftor Name
# SWEDEN             AstraZeneca                            3208048.0
# BANGLADESH         Intrnl Centre Diarrheal Disease        1382896.0
# TANZANIA           Haydom Lutheran Hospital d/b/a Hayd    1100553.0
#                    Haydom Luther Hospital                 1035339.0
# SWITZERLAND        Lawrence D & Karin S Howell            1000000.0
# dtype: float64

# %% [markdown]
# ## Bar plot of top countries giving to UVA

# %%
top_countries_uva = uva.groupby('Country of Giftor')['Foreign Gift Amount'].sum().sort_values(ascending = False).head(20)
sns.barplot(x = top_countries_uva.values, y = top_countries_uva.index)
plt.xlabel('Total Foreign Gift Amount')
plt.ylabel('Top Countries Giving to UVA')
plt.title('Top 10 Countries by Total Amount of Gifts ($) to UVA')
plt.show()

# %% [markdown]
# # Comparing VA schools

# %% [markdown]
# ## New Subset DF

# %%
va_names = ['University of Virginia', 'Virginia Polytechnic Institute & State University', 'Virginia Commonwealth University', 'George Mason University', 'College of William & Mary']
va_schools = df[df['Institution Name'].isin(va_names)]
va_schools
# Out:
#           ID   OPEID                                   Institution Name  \
# 26103  26104  370500                          College of William & Mary
# 26104  26105  370500                          College of William & Mary
# 26105  26106  370500                          College of William & Mary
# 26106  26107  370500                          College of William & Mary
# 26107  26108  370500                          College of William & Mary
# ...      ...     ...                                                ...
# 26390  26391  375400  Virginia Polytechnic Institute & State University
# 26391  26392  375400  Virginia Polytechnic Institute & State University
# 26392  26393  375400  Virginia Polytechnic Institute & State University
# 26393  26394  375400  Virginia Polytechnic Institute & State University
# 26394  26395  375400  Virginia Polytechnic Institute & State University
#
#                City State  Foreign Gift Received Date  Foreign Gift Amount  \
# ...

# %% [markdown]
# ### Flow Chart (Country to Virginia Schools)

# %%
import plotly.graph_objects as go
#giftor = 'Giftor Name'
giftor = 'Country of Giftor'
recipi = 'Institution Name'
flow = 'Foreign Gift Amount'
N = 25

flows = (
    va_schools.groupby([giftor, 
                recipi])
      [flow]
      .sum()
      .nlargest(N)
      .reset_index()
)

labels = (
    flows[giftor].tolist()
    + flows[recipi].tolist()
)

labels = list(dict.fromkeys(labels))

fig = go.Figure(
    go.Sankey(
        node=dict(label=labels),
        link=dict(
            source=flows[giftor]
                        .map(labels.index),
            target=flows[recipi]
                        .map(labels.index),
            value=flows[flow]
        )
    )
)

fig.show()

# %% [markdown]
# ### Count of gifts by VA school

# %%
va_counts = va_schools.groupby('Institution Name')['Foreign Gift Amount'].size().sort_values(ascending = False)
sns.barplot(x = va_counts.values, y = va_counts.index)
plt.xlabel('Number of Gifts')
plt.ylabel('Institution')
plt.title('Number of Foreign Gifts: Virginia Schools')
plt.show()

# %% [markdown]
# ### Mean gift size by VA School

# %%
va_mean = va_schools.groupby('Institution Name')['Foreign Gift Amount'].mean().sort_values(ascending = False)
sns.barplot(x = va_mean.values, y = va_mean.index)
plt.xlabel('Average Gift Amount')
plt.ylabel('Institution')
plt.title('Average Foreign Gift Size: Virginia Schools')
plt.show()
